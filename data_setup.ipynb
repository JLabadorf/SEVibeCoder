# %%
from git import Repo
import os

wiki_repo_path = "https://github.com/malware-dev/MDK-SE.wiki.git"
local_repo_path = "documentation"

if not os.path.exists(local_repo_path):
    print(f"Cloning {wiki_repo_path} into {local_repo_path}...")
    Repo.clone_from(wiki_repo_path, local_repo_path)
else:
    print(f"Updating {local_repo_path}...")
    repo = Repo(local_repo_path)
    repo.remotes.origin.pull()
# Out:
# Cloning https://github.com/malware-dev/MDK-SE.wiki.git into documentation...

# %%
import markdown
from bs4 import BeautifulSoup
import nltk 

nltk.download('punkt')
nltk.download('punkt_tab')

#we are now going to convert the markdown files to html and then extract the text from them. Chunking the text with meta data whether it is text or code.
def load_and_chunk_wiki_mdkse_code_aware(wiki_folder, chunk_size=1000, chunk_overlap=50):
    chunks = []

    # Process files in the root wiki folder
    for filename in os.listdir(wiki_folder):
        if filename.endswith(".md"):
            filepath = os.path.join(wiki_folder, filename)
            page_chunks = process_markdown_file(filepath, filename, chunk_size, chunk_overlap)
            chunks.extend(page_chunks)

    # Process files in the "api" subfolder (if it exists)
    api_folder_path = os.path.join(wiki_folder, "api")
    if os.path.exists(api_folder_path) and os.path.isdir(api_folder_path):
        for filename in os.listdir(api_folder_path):
            if filename.endswith(".md"): # Or other file types you want to process in "api"
                filepath = os.path.join(api_folder_path, filename)
                page_chunks = process_markdown_file(filepath, os.path.join("api", filename), chunk_size, chunk_overlap) # Source includes "api/" prefix
                chunks.extend(page_chunks)

    return chunks


def process_markdown_file(filepath, source_filename, chunk_size, chunk_overlap):
    """Processes a single Markdown file to extract text and code chunks."""
    chunks = []
    chunk_count = 0
    current_chunk = ""

    with open(filepath, "r", encoding="utf-8") as f:
        markdown_content = f.read()
        html_content = markdown.markdown(markdown_content)
        soup = BeautifulSoup(html_content, "html.parser")

        for element in soup.descendants:
            if element.name == 'code':
                code_text = element.get_text(separator='\n', strip=True)
                if code_text.strip():
                    code_chunk = {
                        "content": code_text,
                        "source": source_filename, # Use the provided source_filename
                        "chunk_id": f"{source_filename}_chunk_{chunk_count}_code", # Source in chunk ID too
                        "block_type": "code"
                    }
                    chunks.append(code_chunk)
                    chunk_count += 1
            elif element.name not in ['pre', 'code']:
                text = element.get_text(separator='\n', strip=True)
                if text.strip():
                    sentences = nltk.sent_tokenize(text)
                    for sentence in sentences:
                        if len(current_chunk) + len(sentence) + 1 <= chunk_size:
                            current_chunk += sentence + " "
                        else:
                            if current_chunk.strip():
                                text_chunk = {
                                    "content": current_chunk.strip(),
                                    "source": source_filename, # Use the provided source_filename
                                    "chunk_id": f"{source_filename}_chunk_{chunk_count}_text", # Source in chunk ID too
                                    "block_type": "text"
                                }
                                chunks.append(text_chunk)
                                chunk_count += 1
                            current_chunk = sentence + " "

        if current_chunk.strip():
            text_chunk = {
                "content": current_chunk.strip(),
                "source": source_filename, # Use the provided source_filename
                "chunk_id": f"{source_filename}_chunk_{chunk_count}_text", # Source in chunk ID too
                "block_type": "text"
            }
            chunks.append(text_chunk)

    return chunks


mdk_se_wiki_folder = "documentation" # Your cloned wiki folder
mdk_se_wiki_chunks = load_and_chunk_wiki_mdkse_code_aware(mdk_se_wiki_folder)
print(f"Generated {len(mdk_se_wiki_chunks)} chunks for MDK-SE Wiki (including 'api' folder).")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\James
# [nltk_data]     Labadorf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\James
# [nltk_data]     Labadorf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Generated 16448 chunks for MDK-SE Wiki (including 'api' folder).

# %%
from sentence_transformers import SentenceTransformer

def embed_chunks(chunks, embedding_model):
    """Embeds text chunks using a Sentence Transformer model."""
    embeddings_data = []
    for chunk in chunks:
        embedding_vector = embedding_model.encode(chunk["content"])
        embeddings_data.append({
            "chunk_id": chunk["chunk_id"],
            "embedding": embedding_vector.tolist(),  # Store as list for JSON serialization if needed
            "content": chunk["content"],
            "source": chunk["source"],
            "block_type": chunk["block_type"] # Keep block_type metadata
        })
    return embeddings_data
# --- Use the GPU if available ---
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- Initialize Embedding Model ---
embedding_model_name = "all-mpnet-base-v2"  # Or "all-MiniLM-L6-v2" for faster, smaller embeddings
embedding_model = SentenceTransformer(embedding_model_name)

# --- Embed the Chunks ---
embedded_chunks = embed_chunks(mdk_se_wiki_chunks, embedding_model) # Assuming 'mdk_se_wiki_chunks' is from Step 2
print(f"Generated embeddings for {len(embedded_chunks)} chunks.")
# Out:
# Generated embeddings for 16448 chunks.

# %%
import faiss
import numpy as np
import json  # To save metadata
from tqdm.notebook import tqdm
import os  # To handle file paths

# --- Configuration ---
index_file_path = "faiss_index.bin"
metadata_file_path = "metadata.json"

def index_embeddings_faiss(embedded_chunks):
    """Indexes embeddings in FAISS and saves the index and metadata to files."""
    num_chunks = len(embedded_chunks)
    if num_chunks == 0:
        print("No chunks to index.")
        return

    # Extract embeddings and metadata
    embeddings_list = [chunk_data["embedding"] for chunk_data in embedded_chunks]
    # Convert embeddings to numpy array of float32 (FAISS requirement)
    embeddings_np = np.array(embeddings_list).astype('float32')
    ids = [chunk_data["chunk_id"] for chunk_data in embedded_chunks]
    metadatas = [{"source": chunk_data["source"], "block_type": chunk_data["block_type"]} for chunk_data in embedded_chunks]
    documents = [chunk_data["content"] for chunk_data in embedded_chunks]

    # --- Build FAISS Index ---
    dimension = embeddings_np.shape[1]  # Get embedding dimension
    index = faiss.IndexFlatL2(dimension)  # Using L2 distance (Euclidean), you can choose other index types
    index.add(embeddings_np)  # Add embeddings to the index

    # --- Save FAISS Index to File ---
    faiss.write_index(index, index_file_path)
    print(f"FAISS index saved to: {index_file_path}")

    # --- Save Metadata to JSON File ---
    metadata_to_save = []
    for i in range(num_chunks):
        metadata_to_save.append({
            "id": ids[i],
            "metadata": metadatas[i],
            "document": documents[i]
        })

    with open(metadata_file_path, 'w') as f:
        json.dump(metadata_to_save, f, indent=4) # indent for pretty printing
    print(f"Metadata saved to: {metadata_file_path}")
    print(f"Finished indexing {num_chunks} documents in FAISS.")


index_embeddings_faiss(embedded_chunks)
# Out:
# FAISS index saved to: faiss_index.bin
# Metadata saved to: metadata.json
# Finished indexing 16448 documents in FAISS.

# %%
import faiss
import numpy as np
import json  # To load metadata
from sentence_transformers import SentenceTransformer # Import SentenceTransformer

index_file_path = "faiss_index.bin" # Make sure this matches where you saved your index
metadata_file_path = "metadata.json" # Make sure this matches where you saved your metadata

# --- Load FAISS Index ---
loaded_index = faiss.read_index(index_file_path)

# --- Load Metadata ---
with open(metadata_file_path, 'r') as f:
    loaded_metadata = json.load(f)

def retrieve_relevant_chunks_faiss(query, embedding_model, loaded_index, loaded_metadata, top_k=15):
    """
    Retrieves relevant chunks from FAISS index based on a user query.

    Args:
        query (str): The user query.
        embedding_model: The Sentence Transformer embedding model.
        loaded_index: The loaded FAISS index.
        loaded_metadata: The loaded metadata from JSON.
        top_k (int, optional): The number of top chunks to retrieve. Defaults to 15.

    Returns:
        list: A list of dictionaries, where each dictionary represents a retrieved chunk
              and contains 'content' and 'source' keys.
    """
    query_embedding = embedding_model.encode(query).astype('float32').reshape(1, -1) # Encode query and reshape for FAISS
    distances, indices = loaded_index.search(query_embedding, top_k)

    retrieved_chunks = []
    if indices.any() and indices[0][0] != -1: # Check if results are found
        for i in range(len(indices[0])):
            index_result = indices[0][i]
            if index_result != -1: # Double check for valid index, although should be valid in this setup
                distance = distances[0][i]
                metadata_result = loaded_metadata[index_result] # Access metadata using the FAISS index
                retrieved_chunks.append({
                    "content": metadata_result['document'], # Get document content from metadata
                    "source": metadata_result['metadata']['source'], # Get source from metadata
                    "block_type": metadata_result['metadata']['block_type'], # Get block_type from metadata
                    "distance": distance
                })
    else:
        print("No relevant chunks found.")

    return retrieved_chunks


def test_retrieval_faiss(query, embedding_model, loaded_index, loaded_metadata):
    """
    Tests the retrieval function and prints the retrieved chunks using FAISS.
    """
    print(f"\n--- FAISS Retrieval Test ---")
    print(f"Query: '{query}'")

    retrieved_chunks = retrieve_relevant_chunks_faiss(query, embedding_model, loaded_index, loaded_metadata)

    if retrieved_chunks:
        print(f"\nRetrieved Chunks (Top {len(retrieved_chunks)}):")
        for i, chunk in enumerate(retrieved_chunks):
            print(f"\nChunk {i+1}:")
            print(f"  Source: {chunk['source']}")
            print(f"  Block Type: {chunk['block_type']}") # Print block_type metadata
            print(f"  Distance: {chunk['distance']:.4f}") # Print distance score
            print(f"  Content:\n{chunk['content']}")
    else:
        print("No relevant chunks retrieved for this query.")


# --- Load Sentence Transformer Embedding Model ---
# Choose a pre-trained model from Sentence Transformers.
# 'all-mpnet-base-v2' is a good general-purpose model that balances performance and speed.
embedding_model_name = 'all-mpnet-base-v2' # You can change this to other models
embedding_model = SentenceTransformer(embedding_model_name)

# --- Example Query - Change this to a question relevant to MDK-SE Wiki
test_query = "program a script that will open a door every 5 seconds in space engineers"

test_retrieval_faiss(test_query, embedding_model, loaded_index, loaded_metadata) # Run the FAISS retrieval test
# Out:
# --- FAISS Retrieval Test ---
# Query: 'program a script that will open a door every 5 seconds in space engineers'
#
# Retrieved Chunks (Top 15):
#
# Chunk 1:
#   Source: _Sidebar.md
#   Block Type: text
#   Distance: 0.9012
#   Content:
# Quick Introduction to Space Engineers Ingame Scripts Quick Introduction to Space Engineers Ingame Scripts The Anatomy of a Script
# Your First Script
# Continuous Running No Timers Needed
# The Grid Terminal System
# Block Groups
# Handling Script Arguments
# The Runtime
# The Storage String
# Get The Running Programmable Block
# Do's and Don'ts The Anatomy of a Script The Anatomy of a Script The Anatomy of a Script Your First Script Your First Script Your First Script Continuous Running No Timers Needed
#
# Chunk 2:
#   Source: _Sidebar.md
#   Block Type: text
#   Distance: 0.9281
#   Content:
# List of Available Properties and Actions List of Available Properties and Actions List of Available Properties and Actions List of Available Properties and Actions Quick Introduction to Space Engineers Ingame Scripts
# The Anatomy of a Script
# Your First Script
# Continuous Running No Timers Needed
# The Grid Terminal System
# Block Groups
# Handling Script Arguments
# The Runtime
# The Storage String
# Get The Running Programmable Block
# Do's and Don'ts Quick Introduction to Space Engineers Ingame Scripts
#
# Chunk 3:
#   Source: api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.md
#   Block Type: text
#   Distance: 1.0499
#   Content:
# Determines the linear velocities in meters per second at the block position void OpenDoor() void OpenDoor() void OpenDoor() Opens the door. See
# Status
# to get the current status. Opens the door. See
# Status
# to get the current status. Opens the door. See Status Status to get the current status. void ToggleDoor() void ToggleDoor() void ToggleDoor() Toggles the open state of this door. See
# Status
# to get the current status. Toggles the open state of this door. See
# Status
# to get the current status.
#
# Chunk 4:
#   Source: api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.md
#   Block Type: text
#   Distance: 1.0505
#   Content:
# Toggles the open state of this door. See Status Status to get the current status. bool TryGetClosestPoint(out Vector3D? closestPoint) bool TryGetClosestPoint(out Vector3D? closestPoint) bool TryGetClosestPoint(out Vector3D? closestPoint) void GetActions(List<ITerminalAction> resultList, Func<ITerminalAction, bool> collect = null) void GetActions(List<ITerminalAction> resultList, Func<ITerminalAction, bool> collect = null)
#
# Chunk 5:
#   Source: _Sidebar.md
#   Block Type: text
#   Distance: 1.0595
#   Content:
# Deploying Your Script to Space Engineers
# Script Project Settings
# Adapting Existing Scripts
# Mixin Projects (Shared Projects)
# API Index
# By namespaces
# Whitelist Overview
# Type Definition Listing
# Blocks
# |
# Components
# Blueprints
# |
# Ingots
# |
# Ores
# |
# Gas
# Tools
# |
# Magazines
# |
# Other
# Terminal Properties and Actions
# List of Available Properties and Actions
# Quick Introduction to Space Engineers Ingame Scripts
# The Anatomy of a Script
# Your First Script
# Continuous Running No Timers Needed
# The Grid Terminal System
# Block Groups
# Handling Script Arguments
# The Runtime
# The Storage String
# Get The Running Programmable Block
# Do's and Don'ts
# Advanced Techniques
# The Minifier
# Text Panels and Drawing Sprites
# Sprite Listing
# Antenna Communication (IGC)
# Handling Configuration and Storage
# The EntityId
# Debugging Your Scripts
# Visual debug with a mod
# Debugging with dnSpy
# dnSpy tips and tricks
# Profiling the Game
# Coroutines - Run operations over multiple ticks
# Setting up Visual Studio for MDK contribution
# Math
# PID Controllers
# Vector Transformations with World Matrices
# Finding a block's orientation
#
# Chunk 6:
#   Source: api\Sandbox.Game.Localization.MySpaceTexts.md
#   Block Type: text
#   Distance: 1.0772
#   Content:
# static MyStringId BlockPropertyTitle_ThrustOverride static MyStringId BlockPropertyTitle_ThrustOverride Thrust override Thrust override Thrust override static MyStringId BlockPropertyTitle_TimerStart static MyStringId BlockPropertyTitle_TimerStart Start Start Start static MyStringId BlockPropertyTitle_TimerStop static MyStringId BlockPropertyTitle_TimerStop Stop Stop Stop static MyStringId BlockPropertyTitle_TimerToolbarOpen static MyStringId BlockPropertyTitle_TimerToolbarOpen Setup actions
#
# Chunk 7:
#   Source: api\Sandbox.ModAPI.Ingame.IMyAirtightSlideDoor.md
#   Block Type: text
#   Distance: 1.0781
#   Content:
# ←
# Index
# ←
# Namespace Index ← Index Index ← Namespace Index Namespace Index IMyAirtightSlideDoor Interface IMyAirtightSlideDoor Interface csharp
# public interface IMyAirtightSlideDoor: IMyAirtightDoorBase, IMyDoor, IMyFunctionalBlock, IMyTerminalBlock, IMyCubeBlock, IMyEntity csharp
# public interface IMyAirtightSlideDoor: IMyAirtightDoorBase, IMyDoor, IMyFunctionalBlock, IMyTerminalBlock, IMyCubeBlock, IMyEntity Describes air tight slide door block (PB scripting interface)
#
# Chunk 8:
#   Source: IGC-Example-2-Toggle-Lights.md
#   Block Type: text
#   Distance: 1.0807
#   Content:
# *
#  * This Example source:
#  *  https://github.com/Wicorel/WicoSpaceEngineers/tree/master/MDK%20IGC%20Example%202 * This is MDK IGC Example 2 by wicorel
#  *
#  * Takes the first example script of toggling a light and makes it work via IGC. *
#  * Go to:
#  *  https://github.com/malware-dev/MDK-SE/wiki/Quick-Introduction-to-Space-Engineers-Ingame-Scripts
#  *  to learn more about ingame scripts.
#
# Chunk 9:
#   Source: api\Sandbox.ModAPI.Ingame.IMyDoor.ToggleDoor.md
#   Block Type: text
#   Distance: 1.0839
#   Content:
# ←
# Index
# ←
# Namespace Index
# ←
# IMyDoor ← Index Index ← Namespace Index Namespace Index ← IMyDoor IMyDoor Summary Summary csharp
# public void ToggleDoor() csharp
# public void ToggleDoor() Toggles the open state of this door. See
# Status
# to get the current status. Toggles the open state of this door. See Status Status to get the current status.
#
# Chunk 10:
#   Source: IGC-Example-2-Toggle-Lights.md
#   Block Type: text
#   Distance: 1.0961
#   Content:
# *
#  * This Example source:
#  *  https://github.com/Wicorel/WicoSpaceEngineers/tree/master/MDK%20IGC%20Example%202
# / ```csharp
# / * This is MDK IGC Example 2 by wicorel
#  *
#  * Takes the first example script of toggling a light and makes it work via IGC. *
#  * Go to:
#  *  https://github.com/malware-dev/MDK-SE/wiki/Quick-Introduction-to-Space-Engineers-Ingame-Scripts
#  *  to learn more about ingame scripts.
#
# Chunk 11:
#   Source: api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.ToggleDoor.md
#   Block Type: text
#   Distance: 1.1008
#   Content:
# ←
# Index
# ←
# Namespace Index
# ←
# IMyParachute ← Index Index ← Namespace Index Namespace Index ← IMyParachute IMyParachute Summary Summary csharp
# public void ToggleDoor() csharp
# public void ToggleDoor() Toggles the open state of this door. See
# Status
# to get the current status. Toggles the open state of this door. See Status Status to get the current status.
#
# Chunk 12:
#   Source: api\Sandbox.ModAPI.Ingame.IMyDoor.OpenDoor.md
#   Block Type: text
#   Distance: 1.1022
#   Content:
# ←
# Index
# ←
# Namespace Index
# ←
# IMyDoor ← Index Index ← Namespace Index Namespace Index ← IMyDoor IMyDoor Summary Summary csharp
# public void OpenDoor() csharp
# public void OpenDoor() Opens the door. See
# Status
# to get the current status. Opens the door. See Status Status to get the current status.
#
# Chunk 13:
#   Source: api\Sandbox.ModAPI.Ingame.IMyDoor.OpenRatio.md
#   Block Type: text
#   Distance: 1.1140
#   Content:
# ←
# Index
# ←
# Namespace Index
# ←
# IMyDoor ← Index Index ← Namespace Index Namespace Index ← IMyDoor IMyDoor Summary Summary csharp
# public float OpenRatio { get; } csharp
# public float OpenRatio { get; } The current, accurate ratio of the door's current state where 0 is fully closed and 1 is fully open. The current, accurate ratio of the door's current state where 0 is fully closed and 1 is fully open. Returns Returns float float float
#
# Chunk 14:
#   Source: api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.OpenRatio.md
#   Block Type: text
#   Distance: 1.1146
#   Content:
# ←
# Index
# ←
# Namespace Index
# ←
# IMyParachute ← Index Index ← Namespace Index Namespace Index ← IMyParachute IMyParachute Summary Summary csharp
# public float OpenRatio { get; } csharp
# public float OpenRatio { get; } The current, accurate ratio of the door's current state where 0 is fully closed and 1 is fully open. The current, accurate ratio of the door's current state where 0 is fully closed and 1 is fully open. Returns Returns float float float
#
# Chunk 15:
#   Source: Your-First-Script.md
#   Block Type: text
#   Distance: 1.1191
#   Content:
# Let's start simple. Let's say you have a light, and you want to turn it off and on. Yes, I know, you can just add that to any old toolbar. But it's one of the easiest things you can script, so I say we start there. In fact, let me provide you with
# a finished blueprint with the script in place and ready to go
# . Let's start simple. Let's say you have a light, and you want to turn it off and on. Yes, I know, you can just add that to any old toolbar.

# %%
import importlib 
import gemini_helper
importlib.reload(gemini_helper)
from gemini_helper import generate_answer_gemini

test_query = "program a script that will open a door every 5 seconds in space engineers"


# 1. Retrieve relevant chunks (using your existing function)
retrieved_context = retrieve_relevant_chunks(test_query, embedding_model, collection)

# 2. Generate answer using Gemini API
if retrieved_context:
    gemini_answer = generate_answer_gemini(test_query, retrieved_context)

    print(f"\n--- Gemini API Answer ---")
    print(f"Question: {test_query}")
    print(f"Answer: {gemini_answer}")
    print("\nRetrieved Context Sources:")
    for chunk in retrieved_context:
        print(f"- {chunk['source']}")
else:
    print("No relevant context retrieved, cannot generate answer.")
# Out:
# --- Gemini API Answer ---
# Question: program a script that will open a door every 5 seconds in space engineers
# Answer: Answer:
# ```csharp
# public void Main(string argument, UpdateType updateSource)
# {
#     TimeSpan interval = TimeSpan.FromSeconds(5); // Set the interval to 5 seconds
#     DateTime lastRunTime;
#
#     if (Storage != null && Storage != "") // Load last run time from storage if available
#     {
#         if (DateTime.TryParse(Storage, out lastRunTime))
#         {
#             // Successfully parsed last run time.
#         }
#         else
#         {
#             lastRunTime = DateTime.Now; // If parsing fails, initialize to now
#         }
#     }
#     else
#     {
#         lastRunTime = DateTime.Now; // Initialize last run time if no storage
#     }
#
#     if (DateTime.Now - lastRunTime >= interval)
#     {
#         List<IMyDoor> doorList = new List<IMyDoor>();
#         GridTerminalSystem.GetBlocksOfType<IMyDoor>(doorList);
#
#         if (doorList.Count > 0)
#         {
#             IMyDoor door = doorList[0]; // Get the first door in the list
#             door.OpenDoor();
#             Echo("Door opened!"); // Optional: feedback to programmable block screen
#         }
#         else
#         {
#             Echo("No doors found!"); // Optional: feedback if no doors are found
#         }
#         Storage = DateTime.Now.ToString(); // Store current time for next run
#     }
# }
#
# public Program()
# {
#     Runtime.UpdateFrequency = UpdateFrequency.Update10; // Run every 10 ticks (approx. 1 second)
# }
# ```
#
# **Explanation:**
#
# This script is designed to open a door every 5 seconds in Space Engineers using an in-game programmable block. Here's a breakdown:
#
# 1.  **`public void Main(string argument, UpdateType updateSource)`**: This is the main entry point of your script. It's executed every game tick or when triggered by certain events, depending on the `UpdateType` and `Runtime.UpdateFrequency`.
#
# 2.  **`TimeSpan interval = TimeSpan.FromSeconds(5);`**:  This line defines the desired interval between door openings, set to 5 seconds. `TimeSpan` is used for representing time intervals.
#
# 3.  **`DateTime lastRunTime;`**:  This variable will store the last time the door was opened.
#
# 4.  **Storage Persistence (for remembering the last run time):**
#     *   **`if (Storage != null && Storage != "")`**:  This checks if there's any data stored in the programmable block's `Storage` string from previous runs. `Storage` is a string that persists between script executions, allowing you to save data.
#     *   **`if (DateTime.TryParse(Storage, out lastRunTime))`**:  If there's stored data, it attempts to parse it as a `DateTime` object. `DateTime.TryParse` is used to safely convert a string to a `DateTime`.
#     *   **`else { lastRunTime = DateTime.Now; }`**: If parsing fails (meaning the stored data is not a valid `DateTime` or there's no stored data initially), `lastRunTime` is initialized to the current time (`DateTime.Now`).
#     *   **`else { lastRunTime = DateTime.Now; }`**: This is for the very first run when `Storage` is initially null or empty.
#
# 5.  **Time Check: `if (DateTime.Now - lastRunTime >= interval)`**:
#     *   This is the core logic for the timer. It calculates the time elapsed since `lastRunTime` and checks if it's greater than or equal to the `interval` (5 seconds).
#     *   `DateTime.Now - lastRunTime` gives a `TimeSpan` representing the elapsed time.
#
# 6.  **Door Access and Opening:**
#     *   **`List<IMyDoor> doorList = new List<IMyDoor>();`**:  Creates an empty list to store door blocks. `IMyDoor` is the interface for door blocks in Space Engineers scripting.
#     *   **`GridTerminalSystem.GetBlocksOfType<IMyDoor>(doorList);`**: This is the crucial line for accessing blocks in the game world.
#         *   `GridTerminalSystem` is the central system for interacting with blocks on your grid.
#         *   `GetBlocksOfType<IMyDoor>(doorList)` retrieves all blocks of type `IMyDoor` (doors) on the same grid as the programmable block and adds them to the `doorList`.
#     *   **`if (doorList.Count > 0)`**: Checks if any doors were found.
#     *   **`IMyDoor door = doorList[0];`**:  If doors are found, this line gets the *first* door in the list.  **Important:** If you have multiple doors, this script will only open the first one it finds. You might need to modify this to target a specific door if you have multiple doors and don't want to open them all. You could use `GridTerminalSystem.GetBlockWithName("Door Name")` for a specific door.
#     *   **`door.OpenDoor();`**: This is the method call that actually opens the door. `OpenDoor()` is a method available in the `IMyDoor` interface (as indicated in your context).
#     *   **`Echo("Door opened!");`**:  This is optional. `Echo()` displays text on the programmable block's screen. It's useful for providing feedback that the script is working.
#
# 7.  **Error Handling (No Doors Found):**
#     *   **`else { Echo("No doors found!"); }`**: If `doorList.Count` is 0, it means no doors were found on the grid. This `Echo` message will display "No doors found!" on the programmable block screen, helping you diagnose if there's an issue (like no doors on the grid or a typo in the block type).
#
# 8.  **Storing the Current Time: `Storage = DateTime.Now.ToString();`**:
#     *   After successfully opening the door (or attempting to), this line updates the `Storage` string with the current time (`DateTime.Now.ToString()`).  This ensures that the `lastRunTime` is updated for the next time the script runs, so the 5-second interval is measured correctly from the last door opening.
#
# 9.  **`public Program()`**: This is the constructor of your programmable block script. It's executed once when the script is compiled or when the programmable block is first initialized.
#     *   **`Runtime.UpdateFrequency = UpdateFrequency.Update10;`**: This is crucial for making the script run periodically.
#         *   `Runtime.UpdateFrequency` controls how often the `Main()` method is executed.
#         *   `UpdateFrequency.Update10` tells the game to run the `Main()` method approximately every 10 game ticks. In Space Engineers, there are roughly 60 ticks per second, so `Update10` means the script will run about 6 times per second (every ~0.16 seconds).  This is frequent enough for a 5-second timer to be relatively accurate.  You don't need to run it every tick (`UpdateFrequency.Update1`) for a 5-second interval, which would be less efficient.
#
# **How to use this script in Space Engineers:**
#
# 1.  **Place a Programmable Block:** Build a programmable block on your ship or station.
# 2.  **Open Programmable Block Interface:** Access the programmable block's control panel.
# 3.  **Click "Edit":** Open the script editor.
# 4.  **Clear Existing Code:** Delete any default code in the editor.
# 5.  **Paste the Script:** Copy and paste the C# code provided above into the script editor.
# 6.  **Click "Compile":** Compile the script to check for errors. If there are no errors, it will compile successfully.
# 7.  **Click "Run":**  Run the script.
# 8.  **Ensure Doors are Present:** Make sure you have at least one door block on the same grid as the programmable block.
#
# The door (specifically the first door the script finds) should now open every 5 seconds. You can adjust the `interval` variable in the script to change the opening frequency.
#
# **Important Considerations:**
#
# *   **First Door Found:**  The script currently opens the *first* door it finds. If you have multiple doors and want to control a specific door, you'll need to modify the script to identify doors by name or some other criteria.
# *   **Power Consumption:** Programmable blocks consume a small amount of power when running scripts, especially with `UpdateFrequency` set. However, for a simple script like this running at `Update10`, the power consumption is minimal.
# *   **Error Handling:** The script includes basic error handling (checking for doors and displaying "No doors found!"). You could add more robust error handling if needed, but for this simple task, it's generally sufficient.
# *   **Modifications:** You can easily modify this script to:
#     *   Toggle the door instead of just opening it (use `door.ToggleDoor();`).
#     *   Control multiple doors (loop through `doorList` or use more specific block retrieval methods).
#     *   Use different intervals.
#     *   Trigger the door opening based on other conditions (e.g., sensor activation) instead of a timer.
#
# Retrieved Context Sources:
# - _Sidebar.md
# - _Sidebar.md
# - api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.md
# - api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.md
# - _Sidebar.md
# - api\Sandbox.Game.Localization.MySpaceTexts.md
# - api\Sandbox.ModAPI.Ingame.IMyAirtightSlideDoor.md
# - IGC-Example-2-Toggle-Lights.md
# - api\Sandbox.ModAPI.Ingame.IMyDoor.ToggleDoor.md
# - IGC-Example-2-Toggle-Lights.md
# - api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.ToggleDoor.md
# - api\Sandbox.ModAPI.Ingame.IMyDoor.OpenDoor.md
# - api\Sandbox.ModAPI.Ingame.IMyDoor.OpenRatio.md
# - api\SpaceEngineers.Game.ModAPI.Ingame.IMyParachute.OpenRatio.md
# - Your-First-Script.md
